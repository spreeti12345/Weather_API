# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from datetime import datetime
import time
from citipy import citipy

import os, sys
currentdir = os.path.dirname(os.path.realpath("Weather_Database"))
parentdir = os.path.dirname(currentdir)
sys.path.append(parentdir)
# Import API key
from config import weather_api_key

# Import linregress
from scipy.stats import linregress
import textwrap

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-56.000, high=80.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the lats and longs to a list
coordinates = list(lat_lngs)

# Create a list for holding the cities
cities = []

# Identify the nearest city for each lat and long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we add it to the cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 917

# %%
# Create an empty list to hold weather data
city_data = []
# Print the beginning of the logging
print("Beginning Data Retrieval.     ")
print('------------------------------')

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i>=50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + '&q=' + cities[i]
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retieve data
        city_weather = requests.get(city_url).json()
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descrip = city_weather['weather'][0]['description']
        city_country = city_weather["sys"]["country"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_descrip,
                          "Country": city_country})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# ------------------------------
# Processing Record 1 of Set 1 | lincoln
# Processing Record 2 of Set 1 | zapolyarnyy
# Processing Record 3 of Set 1 | mount isa
# Processing Record 4 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 1 | mar del plata
# Processing Record 6 of Set 1 | bengkulu
# Processing Record 7 of Set 1 | norman wells
# Processing Record 8 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 1 | neuquen
# Processing Record 10 of Set 1 | vagay
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | lasa
# Processing Record 13 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | port-gentil
# Processing Record 16 of Set 1 | george town
# Processing Record 17 of Set 1 | sao filipe
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | salalah
# Processing Record 23 of Set 1 | constitucion
# Processing Record 24 of Set 1 | garden city
# Processing Record 25 of Set 1 | huarmey
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | padang
# Processing Record 28 of Set 1 | lavrentiya
# Processing Record 29 of Set 1 | severo-kurilsk
# Processing Record 30 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | loukhi
# Processing Record 34 of Set 1 | sault sainte marie
# Processing Record 35 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | saint anthony
# Processing Record 38 of Set 1 | saint george
# Processing Record 39 of Set 1 | aljezur
# Processing Record 40 of Set 1 | kizukuri
# Processing Record 41 of Set 1 | aklavik
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | koszalin
# Processing Record 44 of Set 1 | turukhansk
# Processing Record 45 of Set 1 | manaure
# Processing Record 46 of Set 1 | cape town
# Processing Record 47 of Set 1 | baykit
# Processing Record 48 of Set 1 | svetlogorsk
# Processing Record 49 of Set 1 | kapaa
# Processing Record 50 of Set 1 | zhigansk
# Processing Record 1 of Set 2 | thompson
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | hermsdorf
# Processing Record 5 of Set 2 | praia da vitoria
# Processing Record 6 of Set 2 | valparaiso
# Processing Record 7 of Set 2 | sao gabriel da cachoeira
# Processing Record 8 of Set 2 | unity
# Processing Record 9 of Set 2 | port macquarie
# Processing Record 10 of Set 2 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 2 | kearney
# Processing Record 12 of Set 2 | tabou
# Processing Record 13 of Set 2 | broome
# Processing Record 14 of Set 2 | rognan
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | doha
# Processing Record 20 of Set 2 | half moon bay
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 23 of Set 2 | punta arenas
# Processing Record 24 of Set 2 | rio grande
# Processing Record 25 of Set 2 | fulitun
# City not found. Skipping...
# Processing Record 26 of Set 2 | skerries
# Processing Record 27 of Set 2 | buchanan
# Processing Record 28 of Set 2 | port hedland
# Processing Record 29 of Set 2 | tahta
# Processing Record 30 of Set 2 | vanimo
# Processing Record 31 of Set 2 | mayo
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | cidreira
# Processing Record 34 of Set 2 | san patricio
# Processing Record 35 of Set 2 | outjo
# Processing Record 36 of Set 2 | lagoa
# Processing Record 37 of Set 2 | tommot
# Processing Record 38 of Set 2 | tiksi
# Processing Record 39 of Set 2 | dingle
# Processing Record 40 of Set 2 | harper
# Processing Record 41 of Set 2 | kholm
# Processing Record 42 of Set 2 | mnogovershinnyy
# Processing Record 43 of Set 2 | lompoc
# Processing Record 44 of Set 2 | poum
# Processing Record 45 of Set 2 | lagos
# Processing Record 46 of Set 2 | kilindoni
# Processing Record 47 of Set 2 | fort-shevchenko
# Processing Record 48 of Set 2 | surin
# Processing Record 49 of Set 2 | hambantota
# Processing Record 50 of Set 2 | colac
# Processing Record 1 of Set 3 | las palmas
# Processing Record 2 of Set 3 | maneromango
# Processing Record 3 of Set 3 | caravelas
# Processing Record 4 of Set 3 | horta
# Processing Record 5 of Set 3 | manokwari
# Processing Record 6 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 3 | grand gaube
# Processing Record 8 of Set 3 | jumla
# Processing Record 9 of Set 3 | victoria
# Processing Record 10 of Set 3 | caledonia
# Processing Record 11 of Set 3 | esperance
# Processing Record 12 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 13 of Set 3 | astoria
# Processing Record 14 of Set 3 | port hardy
# Processing Record 15 of Set 3 | karratha
# Processing Record 16 of Set 3 | haines junction
# Processing Record 17 of Set 3 | kaitangata
# Processing Record 18 of Set 3 | soe
# Processing Record 19 of Set 3 | skjervoy
# Processing Record 20 of Set 3 | kumta
# Processing Record 21 of Set 3 | hithadhoo
# Processing Record 22 of Set 3 | hunza
# City not found. Skipping...
# Processing Record 23 of Set 3 | innisfail
# Processing Record 24 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 3 | aquiraz
# Processing Record 26 of Set 3 | koungou
# Processing Record 27 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 3 | teya
# Processing Record 29 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 3 | touros
# Processing Record 31 of Set 3 | sorong
# Processing Record 32 of Set 3 | chifeng
# Processing Record 33 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 3 | auki
# Processing Record 35 of Set 3 | nosy varika
# Processing Record 36 of Set 3 | rosarito
# Processing Record 37 of Set 3 | longyearbyen
# Processing Record 38 of Set 3 | puerto el triunfo
# Processing Record 39 of Set 3 | muros
# Processing Record 40 of Set 3 | fonyod
# Processing Record 41 of Set 3 | airai
# Processing Record 42 of Set 3 | saint-leu
# Processing Record 43 of Set 3 | shadegan
# Processing Record 44 of Set 3 | hyeres
# Processing Record 45 of Set 3 | port-de-bouc
# Processing Record 46 of Set 3 | gold coast
# Processing Record 47 of Set 3 | saskylakh
# Processing Record 48 of Set 3 | guadalajara
# Processing Record 49 of Set 3 | helong
# Processing Record 50 of Set 3 | bazarnyye mataki
# Processing Record 1 of Set 4 | itaituba
# Processing Record 2 of Set 4 | fortuna
# Processing Record 3 of Set 4 | sao joao da barra
# Processing Record 4 of Set 4 | buala
# Processing Record 5 of Set 4 | carnarvon
# Processing Record 6 of Set 4 | naze
# Processing Record 7 of Set 4 | bredasdorp
# Processing Record 8 of Set 4 | chuy
# Processing Record 9 of Set 4 | sambava
# Processing Record 10 of Set 4 | sesheke
# Processing Record 11 of Set 4 | port lincoln
# Processing Record 12 of Set 4 | narsaq
# Processing Record 13 of Set 4 | providencia
# Processing Record 14 of Set 4 | khormuj
# City not found. Skipping...
# Processing Record 15 of Set 4 | nikolskoye
# Processing Record 16 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 4 | sungaipenuh
# Processing Record 18 of Set 4 | gannan
# Processing Record 19 of Set 4 | waspan
# Processing Record 20 of Set 4 | sitka
# Processing Record 21 of Set 4 | komsomolskiy
# Processing Record 22 of Set 4 | mahebourg
# Processing Record 23 of Set 4 | balint
# Processing Record 24 of Set 4 | mount gambier
# Processing Record 25 of Set 4 | seddon
# Processing Record 26 of Set 4 | ixtapa
# Processing Record 27 of Set 4 | tura
# Processing Record 28 of Set 4 | maumere
# Processing Record 29 of Set 4 | fairbanks
# Processing Record 30 of Set 4 | stornoway
# Processing Record 31 of Set 4 | ginda
# Processing Record 32 of Set 4 | labuhan
# Processing Record 33 of Set 4 | gemena
# Processing Record 34 of Set 4 | port blair
# Processing Record 35 of Set 4 | adrar
# Processing Record 36 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 4 | katsuura
# Processing Record 38 of Set 4 | cockburn town
# Processing Record 39 of Set 4 | vaitape
# Processing Record 40 of Set 4 | upernavik
# Processing Record 41 of Set 4 | miri
# Processing Record 42 of Set 4 | batemans bay
# Processing Record 43 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 4 | dekalb
# Processing Record 45 of Set 4 | gat
# Processing Record 46 of Set 4 | yulara
# Processing Record 47 of Set 4 | port alfred
# Processing Record 48 of Set 4 | baruun-urt
# Processing Record 49 of Set 4 | alofi
# Processing Record 50 of Set 4 | torbay
# Processing Record 1 of Set 5 | gambela
# Processing Record 2 of Set 5 | camopi
# Processing Record 3 of Set 5 | steamboat springs
# Processing Record 4 of Set 5 | umm lajj
# Processing Record 5 of Set 5 | nizhnevartovsk
# Processing Record 6 of Set 5 | klamath falls
# Processing Record 7 of Set 5 | kodiak
# Processing Record 8 of Set 5 | provideniya
# Processing Record 9 of Set 5 | pacific grove
# Processing Record 10 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 5 | la orilla
# Processing Record 12 of Set 5 | camacha
# Processing Record 13 of Set 5 | sioux lookout
# Processing Record 14 of Set 5 | pinar del rio
# Processing Record 15 of Set 5 | nova olimpia
# Processing Record 16 of Set 5 | castro
# Processing Record 17 of Set 5 | vientiane
# Processing Record 18 of Set 5 | mao
# Processing Record 19 of Set 5 | los llanos de aridane
# Processing Record 20 of Set 5 | fare
# Processing Record 21 of Set 5 | bandarbeyla
# Processing Record 22 of Set 5 | ilulissat
# Processing Record 23 of Set 5 | balingasay
# Processing Record 24 of Set 5 | islamkot
# Processing Record 25 of Set 5 | kalaleh
# Processing Record 26 of Set 5 | hobart
# Processing Record 27 of Set 5 | yeniseysk
# Processing Record 28 of Set 5 | prince rupert
# Processing Record 29 of Set 5 | barcelos
# Processing Record 30 of Set 5 | pangnirtung
# Processing Record 31 of Set 5 | puerto ayora
# Processing Record 32 of Set 5 | dali
# Processing Record 33 of Set 5 | kelo
# Processing Record 34 of Set 5 | gebre guracha
# Processing Record 35 of Set 5 | marrakesh
# Processing Record 36 of Set 5 | hobyo
# Processing Record 37 of Set 5 | vilkija
# Processing Record 38 of Set 5 | geraldton
# Processing Record 39 of Set 5 | panaba
# Processing Record 40 of Set 5 | klaksvik
# Processing Record 41 of Set 5 | pasni
# Processing Record 42 of Set 5 | ostrovnoy
# Processing Record 43 of Set 5 | saint-philippe
# Processing Record 44 of Set 5 | lebu
# Processing Record 45 of Set 5 | barrow
# Processing Record 46 of Set 5 | albany
# Processing Record 47 of Set 5 | mersing
# Processing Record 48 of Set 5 | rocha
# Processing Record 49 of Set 5 | tshela
# Processing Record 50 of Set 5 | walvis bay
# Processing Record 1 of Set 6 | goksun
# Processing Record 2 of Set 6 | kasempa
# Processing Record 3 of Set 6 | ribeira grande
# Processing Record 4 of Set 6 | port elizabeth
# Processing Record 5 of Set 6 | lensk
# Processing Record 6 of Set 6 | sorland
# Processing Record 7 of Set 6 | east london
# Processing Record 8 of Set 6 | kushmurun
# Processing Record 9 of Set 6 | hofn
# Processing Record 10 of Set 6 | haslett
# Processing Record 11 of Set 6 | gornyy
# Processing Record 12 of Set 6 | lorengau
# Processing Record 13 of Set 6 | muzhi
# Processing Record 14 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 15 of Set 6 | nemuro
# Processing Record 16 of Set 6 | vao
# Processing Record 17 of Set 6 | loa janan
# Processing Record 18 of Set 6 | yumen
# Processing Record 19 of Set 6 | nishihara
# Processing Record 20 of Set 6 | quatre cocos
# Processing Record 21 of Set 6 | male
# Processing Record 22 of Set 6 | pasighat
# Processing Record 23 of Set 6 | jerome
# Processing Record 24 of Set 6 | moree
# Processing Record 25 of Set 6 | goderich
# Processing Record 26 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 27 of Set 6 | bambous virieux
# Processing Record 28 of Set 6 | portland
# Processing Record 29 of Set 6 | san carlos
# Processing Record 30 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 6 | igarka
# Processing Record 32 of Set 6 | puerto carreno
# Processing Record 33 of Set 6 | namibe
# Processing Record 34 of Set 6 | ancud
# Processing Record 35 of Set 6 | ahipara
# Processing Record 36 of Set 6 | woodland
# Processing Record 37 of Set 6 | praxedis guerrero
# Processing Record 38 of Set 6 | santa cruz de tenerife
# Processing Record 39 of Set 6 | kamenka
# Processing Record 40 of Set 6 | shelburne
# Processing Record 41 of Set 6 | belgrade
# Processing Record 42 of Set 6 | puerto cabezas
# Processing Record 43 of Set 6 | talnakh
# Processing Record 44 of Set 6 | kinkala
# Processing Record 45 of Set 6 | mareeba
# Processing Record 46 of Set 6 | kysyl-syr
# Processing Record 47 of Set 6 | krasnoselkup
# Processing Record 48 of Set 6 | kralendijk
# Processing Record 49 of Set 6 | nabire
# Processing Record 50 of Set 6 | yar-sale
# Processing Record 1 of Set 7 | ketchikan
# Processing Record 2 of Set 7 | sola
# Processing Record 3 of Set 7 | cerro gordo
# Processing Record 4 of Set 7 | pisco
# Processing Record 5 of Set 7 | camamu
# Processing Record 6 of Set 7 | tual
# Processing Record 7 of Set 7 | comayagua
# Processing Record 8 of Set 7 | grandview
# Processing Record 9 of Set 7 | nanortalik
# Processing Record 10 of Set 7 | ushuaia
# Processing Record 11 of Set 7 | flinders
# Processing Record 12 of Set 7 | high prairie
# Processing Record 13 of Set 7 | inhambane
# Processing Record 14 of Set 7 | rochester
# Processing Record 15 of Set 7 | petropavlovka
# Processing Record 16 of Set 7 | gijon
# Processing Record 17 of Set 7 | muret
# Processing Record 18 of Set 7 | otavi
# Processing Record 19 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 7 | bambanglipuro
# Processing Record 21 of Set 7 | hasaki
# Processing Record 22 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 7 | manicore
# Processing Record 24 of Set 7 | oussouye
# Processing Record 25 of Set 7 | chufarovo
# Processing Record 26 of Set 7 | kutum
# Processing Record 27 of Set 7 | canico
# Processing Record 28 of Set 7 | agirish
# Processing Record 29 of Set 7 | morgan city
# Processing Record 30 of Set 7 | hami
# Processing Record 31 of Set 7 | erzin
# Processing Record 32 of Set 7 | sovetskaya
# Processing Record 33 of Set 7 | ahuimanu
# Processing Record 34 of Set 7 | choya
# Processing Record 35 of Set 7 | bathsheba
# Processing Record 36 of Set 7 | porto walter
# Processing Record 37 of Set 7 | grindavik
# Processing Record 38 of Set 7 | cabedelo
# Processing Record 39 of Set 7 | stephenville
# Processing Record 40 of Set 7 | codrington
# Processing Record 41 of Set 7 | sovetskiy
# Processing Record 42 of Set 7 | bayan
# Processing Record 43 of Set 7 | paka
# Processing Record 44 of Set 7 | benjamin constant
# Processing Record 45 of Set 7 | nouakchott
# Processing Record 46 of Set 7 | alice springs
# Processing Record 47 of Set 7 | samana
# Processing Record 48 of Set 7 | ulladulla
# Processing Record 49 of Set 7 | saint-joseph
# Processing Record 50 of Set 7 | surab
# Processing Record 1 of Set 8 | lardos
# Processing Record 2 of Set 8 | umm kaddadah
# Processing Record 3 of Set 8 | novyy urengoy
# Processing Record 4 of Set 8 | vila franca do campo
# Processing Record 5 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 8 | karpathos
# Processing Record 7 of Set 8 | lakhimpur
# Processing Record 8 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 8 | iqaluit
# Processing Record 10 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 11 of Set 8 | trairi
# Processing Record 12 of Set 8 | celestun
# Processing Record 13 of Set 8 | lazareni
# Processing Record 14 of Set 8 | praia
# Processing Record 15 of Set 8 | lata
# Processing Record 16 of Set 8 | port moresby
# Processing Record 17 of Set 8 | paraiso
# Processing Record 18 of Set 8 | sisophon
# Processing Record 19 of Set 8 | stilfontein
# Processing Record 20 of Set 8 | peru
# Processing Record 21 of Set 8 | goose creek
# Processing Record 22 of Set 8 | keetmanshoop
# Processing Record 23 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 8 | coahuayana
# Processing Record 25 of Set 8 | saint-georges
# Processing Record 26 of Set 8 | margate
# Processing Record 27 of Set 8 | wairoa
# Processing Record 28 of Set 8 | saldanha
# Processing Record 29 of Set 8 | martapura
# Processing Record 30 of Set 8 | ziro
# Processing Record 31 of Set 8 | deputatskiy
# Processing Record 32 of Set 8 | guerrero negro
# Processing Record 33 of Set 8 | lima
# Processing Record 34 of Set 8 | kahului
# Processing Record 35 of Set 8 | virginia beach
# Processing Record 36 of Set 8 | turka
# Processing Record 37 of Set 8 | farah
# Processing Record 38 of Set 8 | gurlan
# Processing Record 39 of Set 8 | byron bay
# Processing Record 40 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 8 | diplo
# Processing Record 42 of Set 8 | zhuhai
# Processing Record 43 of Set 8 | manono
# Processing Record 44 of Set 8 | saint-pierre
# Processing Record 45 of Set 8 | koryazhma
# Processing Record 46 of Set 8 | muroto
# Processing Record 47 of Set 8 | chauk
# Processing Record 48 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 8 | borogontsy
# Processing Record 50 of Set 8 | ponta do sol
# Processing Record 1 of Set 9 | howard springs
# Processing Record 2 of Set 9 | tolaga bay
# Processing Record 3 of Set 9 | anadyr
# Processing Record 4 of Set 9 | coolum beach
# Processing Record 5 of Set 9 | port shepstone
# Processing Record 6 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 7 of Set 9 | clinton
# Processing Record 8 of Set 9 | coaldale
# Processing Record 9 of Set 9 | kidal
# Processing Record 10 of Set 9 | chokurdakh
# Processing Record 11 of Set 9 | alexandria
# Processing Record 12 of Set 9 | leningradskiy
# Processing Record 13 of Set 9 | hamilton
# Processing Record 14 of Set 9 | fez
# Processing Record 15 of Set 9 | montefiascone
# Processing Record 16 of Set 9 | leshukonskoye
# Processing Record 17 of Set 9 | kasongo-lunda
# Processing Record 18 of Set 9 | riverton
# Processing Record 19 of Set 9 | kungurtug
# Processing Record 20 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 21 of Set 9 | vizianagaram
# Processing Record 22 of Set 9 | qasigiannguit
# Processing Record 23 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 9 | clyde river
# Processing Record 25 of Set 9 | changli
# Processing Record 26 of Set 9 | cravo norte
# Processing Record 27 of Set 9 | brae
# Processing Record 28 of Set 9 | westport
# Processing Record 29 of Set 9 | nijar
# Processing Record 30 of Set 9 | yatou
# Processing Record 31 of Set 9 | bilibino
# Processing Record 32 of Set 9 | pointe michel
# Processing Record 33 of Set 9 | buenos aires
# Processing Record 34 of Set 9 | kirkwall
# Processing Record 35 of Set 9 | albesti
# Processing Record 36 of Set 9 | san cristobal
# Processing Record 37 of Set 9 | seoul
# Processing Record 38 of Set 9 | larsnes
# Processing Record 39 of Set 9 | akdepe
# Processing Record 40 of Set 9 | novyy urgal
# Processing Record 41 of Set 9 | qaanaaq
# Processing Record 42 of Set 9 | farafangana
# Processing Record 43 of Set 9 | mangai
# Processing Record 44 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 9 | new norfolk
# Processing Record 46 of Set 9 | khatanga
# Processing Record 47 of Set 9 | penalva
# Processing Record 48 of Set 9 | oranjestad
# Processing Record 49 of Set 9 | lengshuitan
# Processing Record 50 of Set 9 | peski
# Processing Record 1 of Set 10 | makakilo city
# Processing Record 2 of Set 10 | ust-maya
# Processing Record 3 of Set 10 | magugu
# Processing Record 4 of Set 10 | vostok
# Processing Record 5 of Set 10 | kavieng
# Processing Record 6 of Set 10 | paamiut
# Processing Record 7 of Set 10 | opalenica
# Processing Record 8 of Set 10 | goure
# Processing Record 9 of Set 10 | hammerfest
# Processing Record 10 of Set 10 | jining
# Processing Record 11 of Set 10 | miranda
# Processing Record 12 of Set 10 | cherskiy
# Processing Record 13 of Set 10 | luderitz
# Processing Record 14 of Set 10 | bonavista
# Processing Record 15 of Set 10 | rabaul
# Processing Record 16 of Set 10 | aksu
# Processing Record 17 of Set 10 | andros town
# Processing Record 18 of Set 10 | bogandinskiy
# Processing Record 19 of Set 10 | sheridan
# Processing Record 20 of Set 10 | ellisras
# Processing Record 21 of Set 10 | canutama
# Processing Record 22 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 23 of Set 10 | cabo san lucas
# Processing Record 24 of Set 10 | pemba
# Processing Record 25 of Set 10 | itupiranga
# Processing Record 26 of Set 10 | tecoanapa
# Processing Record 27 of Set 10 | balkanabat
# Processing Record 28 of Set 10 | cleveland
# Processing Record 29 of Set 10 | belyy yar
# Processing Record 30 of Set 10 | maniitsoq
# Processing Record 31 of Set 10 | yamada
# Processing Record 32 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 33 of Set 10 | lufilufi
# Processing Record 34 of Set 10 | kulhudhuffushi
# Processing Record 35 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 36 of Set 10 | san quintin
# Processing Record 37 of Set 10 | zorritos
# Processing Record 38 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 10 | chapais
# Processing Record 40 of Set 10 | la libertad
# Processing Record 41 of Set 10 | maralal
# Processing Record 42 of Set 10 | talaya
# Processing Record 43 of Set 10 | okhotsk
# Processing Record 44 of Set 10 | novaya igirma
# Processing Record 45 of Set 10 | basiawan
# Processing Record 46 of Set 10 | salinopolis
# Processing Record 47 of Set 10 | shubarshi
# Processing Record 48 of Set 10 | mugan
# Processing Record 49 of Set 10 | springbok
# Processing Record 50 of Set 10 | farap
# Processing Record 1 of Set 11 | ilovlya
# Processing Record 2 of Set 11 | bend
# Processing Record 3 of Set 11 | pimentel
# Processing Record 4 of Set 11 | socastee
# Processing Record 5 of Set 11 | souillac
# Processing Record 6 of Set 11 | vanino
# Processing Record 7 of Set 11 | quang ngai
# Processing Record 8 of Set 11 | saint-augustin
# Processing Record 9 of Set 11 | camana
# Processing Record 10 of Set 11 | arlit
# Processing Record 11 of Set 11 | acarau
# Processing Record 12 of Set 11 | rio gallegos
# Processing Record 13 of Set 11 | hailar
# Processing Record 14 of Set 11 | iwanai
# Processing Record 15 of Set 11 | amposta
# Processing Record 16 of Set 11 | conceicao da barra
# Processing Record 17 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 18 of Set 11 | novoagansk
# Processing Record 19 of Set 11 | challans
# Processing Record 20 of Set 11 | panguipulli
# Processing Record 21 of Set 11 | winsum
# Processing Record 22 of Set 11 | havelock
# Processing Record 23 of Set 11 | kyra
# Processing Record 24 of Set 11 | lukulu
# Processing Record 25 of Set 11 | windhoek
# Processing Record 26 of Set 11 | wynyard
# Processing Record 27 of Set 11 | gwanda
# Processing Record 28 of Set 11 | catamarca
# Processing Record 29 of Set 11 | opuwo
# Processing Record 30 of Set 11 | herat
# Processing Record 31 of Set 11 | sao jose de ribamar
# Processing Record 32 of Set 11 | tartagal
# Processing Record 33 of Set 11 | okha
# Processing Record 34 of Set 11 | werda
# Processing Record 35 of Set 11 | saint albans
# Processing Record 36 of Set 11 | husavik
# Processing Record 37 of Set 11 | buraydah
# Processing Record 38 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 11 | aragarcas
# Processing Record 40 of Set 11 | andenes
# Processing Record 41 of Set 11 | oranjemund
# Processing Record 42 of Set 11 | dorchester
# Processing Record 43 of Set 11 | nong khae
# Processing Record 44 of Set 11 | mackay
# Processing Record 45 of Set 11 | san angelo
# Processing Record 46 of Set 11 | nome
# Processing Record 47 of Set 11 | reoti
# Processing Record 48 of Set 11 | magelang
# Processing Record 49 of Set 11 | brokopondo
# Processing Record 50 of Set 11 | taoudenni
# Processing Record 1 of Set 12 | laurel
# Processing Record 2 of Set 12 | hay river
# Processing Record 3 of Set 12 | pangody
# Processing Record 4 of Set 12 | anjozorobe
# Processing Record 5 of Set 12 | bluff
# Processing Record 6 of Set 12 | gwembe
# Processing Record 7 of Set 12 | sobolevo
# Processing Record 8 of Set 12 | tawnat
# City not found. Skipping...
# Processing Record 9 of Set 12 | north platte
# Processing Record 10 of Set 12 | svetlyy
# Processing Record 11 of Set 12 | laguna
# Processing Record 12 of Set 12 | belaya gora
# Processing Record 13 of Set 12 | russell
# Processing Record 14 of Set 12 | ypsonas
# Processing Record 15 of Set 12 | rawson
# Processing Record 16 of Set 12 | bayburt
# Processing Record 17 of Set 12 | shingu
# Processing Record 18 of Set 12 | ushtobe
# Processing Record 19 of Set 12 | manoel urbano
# Processing Record 20 of Set 12 | kaihua
# Processing Record 21 of Set 12 | ishigaki
# Processing Record 22 of Set 12 | nam tha
# City not found. Skipping...
# Processing Record 23 of Set 12 | maxixe
# Processing Record 24 of Set 12 | burns lake
# Processing Record 25 of Set 12 | sakakah
# Processing Record 26 of Set 12 | altay
# Processing Record 27 of Set 12 | qui nhon
# Processing Record 28 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 29 of Set 12 | boa vista
# Processing Record 30 of Set 12 | key west
# Processing Record 31 of Set 12 | la ronge
# Processing Record 32 of Set 12 | kem
# Processing Record 33 of Set 12 | mecca
# Processing Record 34 of Set 12 | vilkaviskis
# Processing Record 35 of Set 12 | calbuco
# Processing Record 36 of Set 12 | sande
# Processing Record 37 of Set 12 | coquimbo
# Processing Record 38 of Set 12 | hirara
# Processing Record 39 of Set 12 | batagay-alyta
# Processing Record 40 of Set 12 | aromashevo
# Processing Record 41 of Set 12 | asau
# Processing Record 42 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 43 of Set 12 | jaisinghnagar
# Processing Record 44 of Set 12 | sakata
# Processing Record 45 of Set 12 | plettenberg bay
# Processing Record 46 of Set 12 | tianpeng
# Processing Record 47 of Set 12 | algiers
# Processing Record 48 of Set 12 | kirakira
# Processing Record 49 of Set 12 | iracoubo
# Processing Record 50 of Set 12 | granville
# Processing Record 1 of Set 13 | qeshm
# Processing Record 2 of Set 13 | tuy hoa
# Processing Record 3 of Set 13 | naron
# Processing Record 4 of Set 13 | richards bay
# Processing Record 5 of Set 13 | alugan
# Processing Record 6 of Set 13 | huilong
# Processing Record 7 of Set 13 | sibolga
# Processing Record 8 of Set 13 | hualmay
# Processing Record 9 of Set 13 | winder
# Processing Record 10 of Set 13 | gweru
# Processing Record 11 of Set 13 | santa isabel do rio negro
# Processing Record 12 of Set 13 | ronde
# Processing Record 13 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 14 of Set 13 | nampula
# Processing Record 15 of Set 13 | pevek
# Processing Record 16 of Set 13 | pathalgaon
# Processing Record 17 of Set 13 | rapu-rapu
# Processing Record 18 of Set 13 | alihe
# Processing Record 19 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 21 of Set 13 | junin
# Processing Record 22 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 23 of Set 13 | areosa
# Processing Record 24 of Set 13 | north bend
# Processing Record 25 of Set 13 | hauterive
# Processing Record 26 of Set 13 | aswan
# Processing Record 27 of Set 13 | henties bay
# Processing Record 28 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 29 of Set 13 | tazovskiy
# Processing Record 30 of Set 13 | roebourne
# Processing Record 31 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 13 | chardara
# Processing Record 33 of Set 13 | marsh harbour
# Processing Record 34 of Set 13 | tolmin
# Processing Record 35 of Set 13 | campbellton
# Processing Record 36 of Set 13 | pingzhuang
# Processing Record 37 of Set 13 | kargopol
# Processing Record 38 of Set 13 | banff
# Processing Record 39 of Set 13 | xiaoweizhai
# Processing Record 40 of Set 13 | miles city
# Processing Record 41 of Set 13 | mogadishu
# Processing Record 42 of Set 13 | urucara
# Processing Record 43 of Set 13 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 13 | tabas
# Processing Record 45 of Set 13 | husum
# Processing Record 46 of Set 13 | marsa matruh
# Processing Record 47 of Set 13 | tilichiki
# Processing Record 48 of Set 13 | tenenkou
# Processing Record 49 of Set 13 | parkes
# Processing Record 50 of Set 13 | saint-francois
# Processing Record 1 of Set 14 | kieta
# Processing Record 2 of Set 14 | barra
# Processing Record 3 of Set 14 | ilawa
# Processing Record 4 of Set 14 | leh
# Processing Record 5 of Set 14 | popondetta
# Processing Record 6 of Set 14 | kuvandyk
# Processing Record 7 of Set 14 | huntsville
# Processing Record 8 of Set 14 | chepareria
# Processing Record 9 of Set 14 | nantucket
# Processing Record 10 of Set 14 | najran
# Processing Record 11 of Set 14 | monywa
# Processing Record 12 of Set 14 | monte alegre
# Processing Record 13 of Set 14 | faanui
# Processing Record 14 of Set 14 | lamu
# Processing Record 15 of Set 14 | irbil
# Processing Record 16 of Set 14 | manuk mangkaw
# Processing Record 17 of Set 14 | wanning
# Processing Record 18 of Set 14 | pitimbu
# Processing Record 19 of Set 14 | jiayuguan
# Processing Record 20 of Set 14 | alta floresta
# Processing Record 21 of Set 14 | killybegs
# Processing Record 22 of Set 14 | front royal
# Processing Record 23 of Set 14 | palizada
# Processing Record 24 of Set 14 | fort nelson
# Processing Record 25 of Set 14 | natal
# Processing Record 26 of Set 14 | inuvik
# Processing Record 27 of Set 14 | vila velha
# Processing Record 28 of Set 14 | vihti
# Processing Record 29 of Set 14 | andreapol
# Processing Record 30 of Set 14 | san carlos de bariloche
# Processing Record 31 of Set 14 | araouane
# Processing Record 32 of Set 14 | zhezkazgan
# Processing Record 33 of Set 14 | lhokseumawe
# Processing Record 34 of Set 14 | kefar shemaryahu
# Processing Record 35 of Set 14 | sebinkarahisar
# Processing Record 36 of Set 14 | kruisfontein
# Processing Record 37 of Set 14 | todos santos
# Processing Record 38 of Set 14 | vestmannaeyjar
# Processing Record 39 of Set 14 | port arthur
# Processing Record 40 of Set 14 | xining
# Processing Record 41 of Set 14 | rosendal
# Processing Record 42 of Set 14 | sao jose da tapera
# Processing Record 43 of Set 14 | ambikapur
# Processing Record 44 of Set 14 | kovdor
# Processing Record 45 of Set 14 | bintulu
# Processing Record 46 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 14 | ust-tarka
# Processing Record 48 of Set 14 | savonlinna
# Processing Record 49 of Set 14 | louveira
# Processing Record 50 of Set 14 | havre-saint-pierre
# Processing Record 1 of Set 15 | kabare
# Processing Record 2 of Set 15 | grants
# Processing Record 3 of Set 15 | agdam
# Processing Record 4 of Set 15 | emporia
# Processing Record 5 of Set 15 | sulangan
# Processing Record 6 of Set 15 | onguday
# Processing Record 7 of Set 15 | khandyga
# Processing Record 8 of Set 15 | kirando
# Processing Record 9 of Set 15 | xiongzhou
# Processing Record 10 of Set 15 | vysokogornyy
# Processing Record 11 of Set 15 | kallithea
# Processing Record 12 of Set 15 | xiamen
# Processing Record 13 of Set 15 | namatanai
# Processing Record 14 of Set 15 | chipinge
# Processing Record 15 of Set 15 | manavalakurichi
# Processing Record 16 of Set 15 | koboko
# Processing Record 17 of Set 15 | tateyama
# Processing Record 18 of Set 15 | srednekolymsk
# Processing Record 19 of Set 15 | denia
# Processing Record 20 of Set 15 | atar
# Processing Record 21 of Set 15 | port keats
# Processing Record 22 of Set 15 | burnie
# Processing Record 23 of Set 15 | aviles
# Processing Record 24 of Set 15 | troitskoye
# Processing Record 25 of Set 15 | sinnamary
# Processing Record 26 of Set 15 | beloha
# Processing Record 27 of Set 15 | high level
# Processing Record 28 of Set 15 | panacan
# Processing Record 29 of Set 15 | basco
# Processing Record 30 of Set 15 | college
# Processing Record 31 of Set 15 | pundaguitan
# Processing Record 32 of Set 15 | luchegorsk
# Processing Record 33 of Set 15 | takoradi
# Processing Record 34 of Set 15 | kedougou
# Processing Record 35 of Set 15 | kununurra
# Processing Record 36 of Set 15 | matara
# Processing Record 37 of Set 15 | evensk
# Processing Record 38 of Set 15 | syracuse
# Processing Record 39 of Set 15 | tuatapere
# Processing Record 40 of Set 15 | lodingen
# Processing Record 41 of Set 15 | sisimiut
# Processing Record 42 of Set 15 | patna
# Processing Record 43 of Set 15 | chulman
# Processing Record 44 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 45 of Set 15 | santa catarina de tepehuanes
# Processing Record 46 of Set 15 | anna paulowna
# Processing Record 47 of Set 15 | acapulco
# Processing Record 48 of Set 15 | lebanon
# Processing Record 49 of Set 15 | angoram
# Processing Record 50 of Set 15 | pacasmayo
# Processing Record 1 of Set 16 | ojinaga
# Processing Record 2 of Set 16 | santa marta de tormes
# Processing Record 3 of Set 16 | roald
# Processing Record 4 of Set 16 | dawei
# Processing Record 5 of Set 16 | poshekhonye
# Processing Record 6 of Set 16 | ixtepec
# Processing Record 7 of Set 16 | el reno
# Processing Record 8 of Set 16 | rehoboth
# Processing Record 9 of Set 16 | olafsvik
# Processing Record 10 of Set 16 | gamboma
# Processing Record 11 of Set 16 | adre
# Processing Record 12 of Set 16 | bonnyville
# Processing Record 13 of Set 16 | mangaratiba
# Processing Record 14 of Set 16 | mumford
# Processing Record 15 of Set 16 | tayshet
# Processing Record 16 of Set 16 | nkhata bay
# Processing Record 17 of Set 16 | cayenne
# Processing Record 18 of Set 16 | isangel
# Processing Record 19 of Set 16 | keti bandar
# Processing Record 20 of Set 16 | semnan
# Processing Record 21 of Set 16 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 16 | beira
# Processing Record 23 of Set 16 | mana
# Processing Record 24 of Set 16 | fergus falls
# Processing Record 25 of Set 16 | sal rei
# Processing Record 26 of Set 16 | necochea
# Processing Record 27 of Set 16 | maun
# Processing Record 28 of Set 16 | hearst
# Processing Record 29 of Set 16 | asayita
# City not found. Skipping...
# Processing Record 30 of Set 16 | ust-karsk
# Processing Record 31 of Set 16 | assiniboia
# Processing Record 32 of Set 16 | sohag
# Processing Record 33 of Set 16 | moyale
# Processing Record 34 of Set 16 | faya
# Processing Record 35 of Set 16 | tiarei
# Processing Record 36 of Set 16 | bentiu
# Processing Record 37 of Set 16 | great falls
# Processing Record 38 of Set 16 | kwekwe
# Processing Record 39 of Set 16 | norwich
# Processing Record 40 of Set 16 | isugod
# Processing Record 41 of Set 16 | sembakung
# Processing Record 42 of Set 16 | tautira
# Processing Record 43 of Set 16 | gainesville
# Processing Record 44 of Set 16 | whitehorse
# Processing Record 45 of Set 16 | pontes e lacerda
# Processing Record 46 of Set 16 | pestovo
# Processing Record 47 of Set 16 | tungor
# Processing Record 48 of Set 16 | nouadhibou
# Processing Record 49 of Set 16 | kyaukse
# Processing Record 50 of Set 16 | mancio lima
# Processing Record 1 of Set 17 | coihaique
# Processing Record 2 of Set 17 | riyadh
# Processing Record 3 of Set 17 | terenos
# Processing Record 4 of Set 17 | somerset west
# Processing Record 5 of Set 17 | coetupo
# City not found. Skipping...
# Processing Record 6 of Set 17 | kambja
# Processing Record 7 of Set 17 | beyneu
# Processing Record 8 of Set 17 | sur
# Processing Record 9 of Set 17 | malakal
# Processing Record 10 of Set 17 | baghdad
# Processing Record 11 of Set 17 | udachnyy
# Processing Record 12 of Set 17 | rabat
# Processing Record 13 of Set 17 | bacuit
# City not found. Skipping...
# Processing Record 14 of Set 17 | shimoda
# Processing Record 15 of Set 17 | satitoa
# City not found. Skipping...
# Processing Record 16 of Set 17 | pochutla
# Processing Record 17 of Set 17 | bar harbor
# Processing Record 18 of Set 17 | nyurba
# Processing Record 19 of Set 17 | etne
# Processing Record 20 of Set 17 | smithers
# Processing Record 21 of Set 17 | whitecourt
# Processing Record 22 of Set 17 | luganville
# Processing Record 23 of Set 17 | chingirlau
# Processing Record 24 of Set 17 | ambilobe
# Processing Record 25 of Set 17 | mbaiki
# Processing Record 26 of Set 17 | kavaratti
# Processing Record 27 of Set 17 | asfi
# Processing Record 28 of Set 17 | linguere
# Processing Record 29 of Set 17 | mendeleyevsk
# Processing Record 30 of Set 17 | honiara
# Processing Record 31 of Set 17 | scarborough
# Processing Record 32 of Set 17 | pangai
# Processing Record 33 of Set 17 | novopokrovskaya
# Processing Record 34 of Set 17 | severo-yeniseyskiy
# Processing Record 35 of Set 17 | itarema
# Processing Record 36 of Set 17 | dunedin
# Processing Record 37 of Set 17 | kibakwe
# Processing Record 38 of Set 17 | abha
# Processing Record 39 of Set 17 | miyako
# Processing Record 40 of Set 17 | farafenni
# Processing Record 41 of Set 17 | molina
# Processing Record 42 of Set 17 | tomatlan
# Processing Record 43 of Set 17 | morant bay
# Processing Record 44 of Set 17 | ust-kan
# Processing Record 45 of Set 17 | baoshan
# Processing Record 46 of Set 17 | simao
# Processing Record 47 of Set 17 | villa vazquez
# City not found. Skipping...
# Processing Record 48 of Set 17 | kerema
# Processing Record 49 of Set 17 | eyl
# Processing Record 50 of Set 17 | umm jarr
# City not found. Skipping...
# Processing Record 1 of Set 18 | kloulklubed
# Processing Record 2 of Set 18 | partizansk
# Processing Record 3 of Set 18 | dauriya
# Processing Record 4 of Set 18 | teneguiban
# City not found. Skipping...
# Processing Record 5 of Set 18 | maghama
# City not found. Skipping...
# Processing Record 6 of Set 18 | shaartuz
# City not found. Skipping...
# Processing Record 7 of Set 18 | perth
# Processing Record 8 of Set 18 | pilar
# Processing Record 9 of Set 18 | torbat-e jam
# Processing Record 10 of Set 18 | verkhnyaya inta
# Processing Record 11 of Set 18 | dovers
# Processing Record 12 of Set 18 | curuguaty
# Processing Record 13 of Set 18 | chissamba
# Processing Record 14 of Set 18 | vielsalm
# Processing Record 15 of Set 18 | murgab
# Processing Record 16 of Set 18 | wajid
# Processing Record 17 of Set 18 | neiafu
# Processing Record 18 of Set 18 | batticaloa
# Processing Record 19 of Set 18 | korla
# Processing Record 20 of Set 18 | jiaxing
# Processing Record 21 of Set 18 | verkhnyaya sinyachikha
# Processing Record 22 of Set 18 | cap-aux-meules
# Processing Record 23 of Set 18 | gorelki
# Processing Record 24 of Set 18 | rincon
# Processing Record 25 of Set 18 | porto novo
# Processing Record 26 of Set 18 | magui
# City not found. Skipping...
# Processing Record 27 of Set 18 | nador
# Processing Record 28 of Set 18 | magadan
# Processing Record 29 of Set 18 | ossora
# Processing Record 30 of Set 18 | esmeraldas
# Processing Record 31 of Set 18 | emilio carranza
# Processing Record 32 of Set 18 | jalu
# Processing Record 33 of Set 18 | gorontalo
# Processing Record 34 of Set 18 | vawkavysk
# Processing Record 35 of Set 18 | bandar-e anzali
# Processing Record 36 of Set 18 | orbetello
# Processing Record 37 of Set 18 | ust-kuyga
# Processing Record 38 of Set 18 | charters towers
# Processing Record 39 of Set 18 | manzhouli
# Processing Record 40 of Set 18 | wenzhou
# Processing Record 41 of Set 18 | palmer
# Processing Record 42 of Set 18 | oudtshoorn
# Processing Record 43 of Set 18 | ureki
# Processing Record 44 of Set 18 | xuddur
# Processing Record 45 of Set 18 | portobelo
# Processing Record 46 of Set 18 | cururupu
# Processing Record 47 of Set 18 | mackenzie
# Processing Record 48 of Set 18 | soyo
# Processing Record 49 of Set 18 | kokkola
# Processing Record 50 of Set 18 | maningrida
# Processing Record 1 of Set 19 | marystown
# Processing Record 2 of Set 19 | dolinsk
# Processing Record 3 of Set 19 | kushiro
# Processing Record 4 of Set 19 | szczytno
# Processing Record 5 of Set 19 | oistins
# Processing Record 6 of Set 19 | ca mau
# Processing Record 7 of Set 19 | niihama
# Processing Record 8 of Set 19 | nadym
# Processing Record 9 of Set 19 | ust-omchug
# Processing Record 10 of Set 19 | lazarev
# Processing Record 11 of Set 19 | vanavara
# Processing Record 12 of Set 19 | gamba
# Processing Record 13 of Set 19 | avera
# Processing Record 14 of Set 19 | mayari
# City not found. Skipping...
# Processing Record 15 of Set 19 | chake chake
# Processing Record 16 of Set 19 | teahupoo
# Processing Record 17 of Set 19 | businga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 850

# %%
# Convert the array of dictionaries to a DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Lincoln  40.8000  -96.6670     60.80        82          90
# 1    Zapolyarnyy  69.4154   30.8136     35.60       100          90
# 2      Mount Isa -20.7333  139.5000     75.20        15           0
# 3  Mar Del Plata -38.0023  -57.5575     52.00       100           0
# 4       Bengkulu  -3.8004  102.2655     85.21        68         100
# 5   Norman Wells  65.2820 -126.8329     46.40        57          75
# 6        Neuquen -38.9516  -68.0591     42.80        93           0
# 7          Vagay  57.9375   69.0217     77.77        36          80
# 8         Bethel  41.3712  -73.4140     52.00        87           1
# 9           Lasa  46.6166   10.7002     48.00        93          75
#
#    Wind Speed      Description Country
# 0        8.05  overcast clouds      US
# 1        1.14              fog      RU
# 2       14.97        clear sky      AU
# 3        2.30        clear sky      AR
# 4        4.83  overcast clouds      ID
# 5        4.61    broken clouds      CA
# 6        2.30        clear sky      AR
# 7       10.89    broken clouds      RU
# 8        2.06        clear sky      US
# 9        5.75    broken clouds      IT

# %%
new_column_order = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed', 'Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Lincoln      US  40.8000  -96.6670     60.80        82          90
# 1    Zapolyarnyy      RU  69.4154   30.8136     35.60       100          90
# 2      Mount Isa      AU -20.7333  139.5000     75.20        15           0
# 3  Mar Del Plata      AR -38.0023  -57.5575     52.00       100           0
# 4       Bengkulu      ID  -3.8004  102.2655     85.21        68         100
# 5   Norman Wells      CA  65.2820 -126.8329     46.40        57          75
# 6        Neuquen      AR -38.9516  -68.0591     42.80        93           0
# 7          Vagay      RU  57.9375   69.0217     77.77        36          80
# 8         Bethel      US  41.3712  -73.4140     52.00        87           1
# 9           Lasa      IT  46.6166   10.7002     48.00        93          75
#
#    Wind Speed      Description
# 0        8.05  overcast clouds
# 1        1.14              fog
# 2       14.97        clear sky
# 3        2.30        clear sky
# 4        4.83  overcast clouds
# 5        4.61    broken clouds
# 6        2.30        clear sky
# 7       10.89    broken clouds
# 8        2.06        clear sky
# 9        5.75    broken clouds

# %%
# Create output CSV
output_data_file = 'WeatherPy_Database.csv'
# Export the City_Data into CSV
city_data_df.to_csv(output_data_file, index_label='City_ID')
